# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Shivansh\OneDrive\Desktop\ml datasets\fraudTest.csv\fraudTest.csv')

# %%
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df.groupby('is_fraud').count()
# Out:
#           Unnamed: 0  trans_date_trans_time  cc_num  merchant  category  \
# is_fraud
# 0             553574                 553574  553574    553574    553574
# 1               2145                   2145    2145      2145      2145
#
#              amt   first    last  gender  street  ...     zip     lat    long  \
# is_fraud                                          ...
# 0         553574  553574  553574  553574  553574  ...  553574  553574  553574
# 1           2145    2145    2145    2145    2145  ...    2145    2145    2145
#
#           city_pop     job     dob  trans_num  unix_time  merch_lat  \
# is_fraud
# 0           553574  553574  553574     553574     553574     553574
# 1             2145    2145    2145       2145       2145       2145
#
#           merch_long
# is_fraud
# 0             553574
# 1               2145
#
# [2 rows x 22 columns]

# %%
df = df.drop(['Unnamed: 0',
    'merchant',
    'cc_num',
    'first',
    'zip',
    'last',
    'trans_num',
    'unix_time',
    'street',
    'merch_lat',
    'gender',
    'merch_long',
    'job',
    'trans_date_trans_time'], axis=1)

# %%
df.columns
# Out:
# Index(['category', 'amt', 'city', 'state', 'lat', 'long', 'city_pop', 'dob',
#        'is_fraud'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# category    0
# amt         0
# city        0
# state       0
# lat         0
# long        0
# city_pop    0
# dob         0
# is_fraud    0
# dtype: int64

# %%
from datetime import datetime
df['dob'] = pd.to_datetime(df['dob'])
df['dob'] = df['dob'].dt.year
df['dob'] = datetime.now().year - df['dob']
df = df.rename(columns = {'dob' : 'age'})

# %%
df
# Out:
#               category     amt          city state      lat      long  \
# 0        personal_care    2.86      Columbia    SC  33.9659  -80.9355
# 1        personal_care   29.84       Altonah    UT  40.3207 -110.4360
# 2       health_fitness   41.28      Bellmore    NY  40.6729  -73.5365
# 3             misc_pos   60.05    Titusville    FL  28.5697  -80.8191
# 4               travel    3.19      Falmouth    MI  44.2529  -85.0170
# ...                ...     ...           ...   ...      ...       ...
# 555714  health_fitness   43.77         Luray    MO  40.4931  -91.8912
# 555715       kids_pets  111.84  Lake Jackson    TX  29.0393  -95.4401
# 555716       kids_pets   86.88       Burbank    WA  46.1966 -118.9017
# 555717          travel    7.99          Mesa    ID  44.6255 -116.4493
# 555718   entertainment   38.13        Edmond    OK  35.6665  -97.4798
#
#         city_pop  age  is_fraud
# 0         333497   56         0
# 1            302   34         0
# ...

# %%
x = df.drop(['is_fraud'], axis=1)
colm = x.columns.to_list()
y= df['is_fraud']
col
# Out:
# 'state'

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)
rus.fit(x, y)
x,y = rus.fit_resample(x, y)
y.value_counts()
# Out:
# is_fraud
# 0    2145
# 1    2145
# Name: count, dtype: int64

# %%
num_col = [i for i in x.columns if x[i].dtype == 'int64' or x[i].dtype =='int32' or x[i].dtype =='float64']
cat_col = [i for i in x.columns if x[i].dtype == 'object']

# %%
num_col,cat_col
# Out:
# (['amt', 'lat', 'long', 'city_pop', 'age'], ['category', 'city', 'state'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cat_col:
    x[col] = le.fit_transform(x[col])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x[0]
# Out:
# array([ 0.84639937, -0.22551258, -1.06072817,  0.7624034 , -0.57423168,
#        -0.49658318, -0.29269996, -0.73724405])

# %%
x = pd.DataFrame(x, columns=colm)

# %% [markdown]
# Model Building (Logistic, Decision Tree & Random Forest)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier()
}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return accuracy, precision, recall, f1

# %%
results = {}
for name, model in models.items():
    accuracy, precision, recall, f1 = evaluate_model(model, x_train, y_train, x_test, y_test)
    results[name] = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }
# Create a DataFrame to display the results
results_df = pd.DataFrame(results).T
results_df
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# Logistic Regression  0.850816   0.927954  0.757647  0.834197
# Decision Tree        0.954545   0.948837  0.960000  0.954386
# Random Forest        0.951049   0.950588  0.950588  0.950588

# %% [markdown]
# From the above data Frame, we see Random Forest Prediction is good

# %%
pred = models['Random Forest'].predict(x_test)
if pred[0] == 1:
    print('The  given credit card transaction is a fraud')
else:
    print('The given credit card transaction is not a fraud')
# Out:
# The given credit card transaction is not a fraud

# %%
print
